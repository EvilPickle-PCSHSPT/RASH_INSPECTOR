# %% [markdown]
# # Import Libraries

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import numpy as np

# %%
def random_data_visualize(ad_path, other_path):
    ad_path = (ad_path)
    num_ad = len(os.listdir(ad_path))
    print('Atopic Dermatitis', num_ad)
    
    print('')
    
    other_path = (other_path)
    num_other = len(os.listdir(other_path))
    print('Atopic Dermatitis', num_ad)
    
    classes = ['Atopic Dermatits', 'Other']
    number_image = [num_ad, num_other]
    num_classes = np.arange(len(classes))
    plt.figure(figsize=(12, 4))
    plt.bar(num_classes, number_image)
    plt.xticks(num_classes, classes, fontsize=15)
    plt.xlabel('Classes')
    plt.ylabel('Number of Image')
    plt.show()

# %% [markdown]
# # Arm

# %%
ad_arm_path = '/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/CNN/Dataset/ORGAN/step5_random_dataset/arm/AD'

other_arm_path = '/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/CNN/Dataset/ORGAN/step5_random_dataset/arm/Other'

# %%
random_data_visualize(ad_arm_path, other_arm_path)
# Out:
# Atopic Dermatitis 450
#
# Atopic Dermatitis 450

# %%
num_arm = 450

# %% [markdown]
# # Bodyskin

# %%
ad_bodyskin_path = '/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/CNN/Dataset/ORGAN/step5_random_dataset/bodyskin/AD'

other_bodyskin_path = '/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/CNN/Dataset/ORGAN/step5_random_dataset/bodyskin/Other'

# %%
random_data_visualize(ad_bodyskin_path, other_bodyskin_path)
# Out:
# Atopic Dermatitis 950
#
# Atopic Dermatitis 950

# %%
num_bodyskin = 950

# %% [markdown]
# # Hand

# %%
ad_hand_path = '/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/CNN/Dataset/ORGAN/step5_random_dataset/hand/AD'

other_hand_path = '/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/CNN/Dataset/ORGAN/step5_random_dataset/hand/Other'

# %%
random_data_visualize(ad_hand_path, other_hand_path)
# Out:
# Atopic Dermatitis 250
#
# Atopic Dermatitis 250

# %%
num_hand = 250

# %% [markdown]
# # Leg

# %%
ad_leg_path = '/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/CNN/Dataset/ORGAN/step5_random_dataset/leg/AD'

other_leg_path = '/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/CNN/Dataset/ORGAN/step5_random_dataset/leg/Other'

# %%
random_data_visualize(ad_leg_path, other_leg_path)
# Out:
# Atopic Dermatitis 625
#
# Atopic Dermatitis 625

# %%
num_leg = 625

# %% [markdown]
# # Atopic Dermatitis VS Other

# %%
classes = ['Arm', 'Bodyskin', 'Hand', 'Leg']
num_classes = np.arange(len(classes))

#print(num_classes)

organ_ad_images = (num_arm, num_bodyskin, num_hand, num_leg)
organ_other_images = (num_arm, num_bodyskin, num_hand, num_leg)

#print(organ_ad_images)
#print(organ_other_images)

fig, ax = plt.subplots()
bar_width = 0.35

ad_bar = plt.bar(num_classes, 
                 organ_ad_images, 
                 bar_width, 
                 label='Atopic Dermatitis')

other_bar = plt.bar(num_classes + bar_width, 
                    organ_other_images, 
                    bar_width, 
                    label='Other')

plt.xlabel('Classes')
plt.ylabel('Number of Image')
plt.xticks(num_classes + bar_width, ('Arm', 'Bodyskin', 'Hand', 'Leg'))
plt.legend()
plt.tight_layout()
print(''.center(50))
