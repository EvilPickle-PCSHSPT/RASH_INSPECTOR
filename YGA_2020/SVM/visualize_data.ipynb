# %% [markdown]
# # **Import Libraries**

# %%
import skimage
from skimage.io import imread
from skimage.transform import resize
from sklearn.model_selection import train_test_split
from sklearn.utils import Bunch
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# # **Load Image Files**

# %%
def load_image_files(container_path, dimension=(224, 224)):
    """
    Load image files with categories as subfolder names 
    which performs like scikit-learn sample dataset
    
    Parameters
    ----------
    container_path : string or unicode
        Path to the main folder holding one subfolder per category
    dimension : tuple
        size to which image are adjusted to
        
    Returns
    -------
    Bunch
    """
    image_dir = Path(container_path)
    folders = [directory for directory in image_dir.iterdir() if directory.is_dir()]
    categories = [fo.name for fo in folders]

    descr = "A image classification dataset"
    images = []
    flat_data = []
    target = []
    for i, direc in enumerate(folders):
        for file in direc.iterdir():
            img = skimage.io.imread(file)
            img_resized = resize(img, dimension, anti_aliasing=True, mode='reflect')
            flat_data.append(img_resized.flatten()) 
            images.append(img_resized)
            target.append(i)
    flat_data = np.array(flat_data)
    target = np.array(target)
    images = np.array(images)

    return Bunch(data=flat_data,
                 target=target,
                 target_names=categories,
                 images=images,
                 DESCR=descr)

# %% [markdown]
# # **PCA ???***
# I think it's a PCA method.

# %% [markdown]
# # Arm

# %%
arm_image_dataset = load_image_files('/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/SVM_RASH_INSPECTOR/augmented_data/arm')

# %%
X_train, X_test, y_train, y_test = train_test_split(
    arm_image_dataset.data, arm_image_dataset.target, test_size=0.2,random_state=20)

# %%
plt.scatter(X_train[:, -0], X_train[:, 1], c=y_train, s=50, cmap=plt.cm.Paired )
plt.show()

# %% [markdown]
# # Bodyskin

# %%
bodyskin_image_dataset = load_image_files('/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/SVM_RASH_INSPECTOR/augmented_data/bodyskin')

# %%
X_train, X_test, y_train, y_test = train_test_split(
    bodyskin_image_dataset.data, bodyskin_image_dataset.target, test_size=0.2,random_state=20)

# %%
plt.scatter(X_train[:, -0], X_train[:, 1], c=y_train, s=50, cmap=plt.cm.Paired )
plt.show()

# %% [markdown]
# # Hand

# %%
hand_image_dataset = load_image_files('/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/SVM_RASH_INSPECTOR/augmented_data/hand')

# %%
X_train, X_test, y_train, y_test = train_test_split(
    hand_image_dataset.data, hand_image_dataset.target, test_size=0.2,random_state=20)

# %%
plt.scatter(X_train[:, -0], X_train[:, 1], c=y_train, s=50, cmap=plt.cm.Paired )
plt.show()

# %% [markdown]
# # Leg

# %%
leg_image_dataset = load_image_files('/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/SVM_RASH_INSPECTOR/augmented_data/leg')

# %%
X_train, X_test, y_train, y_test = train_test_split(
    leg_image_dataset.data, leg_image_dataset.target, test_size=0.2,random_state=20)

# %%
plt.scatter(X_train[:, -0], X_train[:, 1], c=y_train, s=50, cmap=plt.cm.Paired )
plt.show()
