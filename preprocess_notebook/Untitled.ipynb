# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mping
from skimage import exposure
from skimage.util import random_noise
from skimage import transform
from skimage.filters import median
import random

# %%
#for i, img in enumerate():

# %%
img = mping.imread('/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/Dataset/ORGAN/step3_resized_data/leg/AD/AD_leg_3.jpg', -1)
plt.imshow(img)
#print(img)

# %%
horizontal = np.fliplr(img)
plt.imshow(horizontal)
cv2.imwrite('hee.jpg', horizontal)
# Out:
# True

# %%
vertical = np.flipud(img)
plt.imshow(vertical)
plt.imsave('kuy.jpg', vertical)

# %%
rotate = transform.rotate(img, -30)
plt.imshow(rotate)
plt.imsave('kuy.jpg', rotate)

# %%
noise_img = random_noise(img)
plt.imshow(noise_img)

# %%
bright = exposure.adjust_gamma(img, gamma=0.5, gain=1)
dark = exposure.adjust_gamma(img, gamma=1.5, gain=1)

plt.imshow(bright)

cv2.imwrite('kuy', bright)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-16-59a472fc4784> in <module>
#       4 plt.imshow(bright)
#       5
# ----> 6 cv2.imwrite('kuy', bright)
#
# error: OpenCV(4.1.1) /Users/travis/build/skvark/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp:662: error: (-2:Unspecified error) could not find a writer for the specified extension in function 'imwrite_'

# %%
plt.imshow(dark)

# %%
rd_rotate = transform.rotate(img, random.uniform(0, 360))
plt.imshow(rd_rotate)

# %%
noise = random_noise(dark)
plt.imshow(noise)
cv2.imwrite('kuy', )
