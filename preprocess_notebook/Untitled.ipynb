# %%
import cv2
import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
data_path = glob.glob('/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/Dataset/original_data/Allergy/AtopicDermatitis/arm/*.jpg')

new_path = '/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/Dataset/norm/norm_{}.jpg'

# %%
def resize_normalization(input_path, output_path):
    
    image_size = 224
    dim = (image_size, image_size)
    
    for i, img in enumerate(input_path):
        image = cv2.imread(img)
        resized_image = cv2.resize(image, dim)
        normalized_image = np.array((resized_image-np.min(resized_image))/(np.max(resized_image)-np.min(resized_image)))
        cv2.imwrite(output_path.format(i), normalized_image)
        plt.imshow(normalized_image)

# %%
resize_normalization(data_path, new_path)

# %%
#cv2.imread('/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/Dataset/renorm/AtopicDermatitis/arm/norm_2.jpg')

# %%
#cv2.imread('/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/Dataset/original_data/Allergy/AtopicDermatitis/arm/dq042768HB-768x505.jpg')

# %%
from numpy import asarray
from PIL import Image

# load image
image = Image.open('/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/Dataset/original_data/Allergy/AtopicDermatitis/arm/dq042768HB-768x505.jpg')
pic = asarray(image)
# convert from integers to floats
pic = pic.astype('float32')
# normalize to the range 0-1
pic /= 255.0
plt.imshow(pic)
#plt.show()

# %%
cv2.imread('/Users/waranthornchansawang/Desktop/RASH_INSPECTOR/Dataset/original_data/Allergy/AtopicDermatitis/arm/dq042768HB-768x505.jpg')
# Out:
# array([[[240, 197, 134],
#         [235, 191, 130],
#         [228, 184, 125],
#         ...,
#         [ 11,   4,   0],
#         [  5,   2,   0],
#         [  9,  10,   8]],
#
#        [[230, 187, 124],
#         [228, 184, 123],
#         [224, 180, 121],
#         ...,
#         [ 16,   7,   0],
#         [ 10,   7,   2],
#         [  2,   3,   1]],
#
#        [[225, 181, 118],
#         [224, 179, 118],
#         [225, 179, 121],
#         ...,
#         [ 20,  11,   1],
#         [ 16,  12,   7],
#         [ 13,  12,   8]],
#
#        ...,
#
#        [[143, 106,  78],
#         [142, 105,  77],
#         [138, 103,  77],
#         ...,
#         [ 89,  64,  48],
#         [ 53,  30,  15],
#         [ 37,  14,   0]],
#
#        [[136,  99,  71],
#         [135,  98,  70],
#         [131,  96,  70],
#         ...,
#         [113,  88,  72],
#         [ 79,  56,  41],
#         [ 47,  24,   9]],
#
#        [[129,  92,  64],
#         [135,  98,  70],
#         [136,  99,  71],
#         ...,
#         [115,  90,  74],
#         [ 74,  51,  36],
#         [ 38,  15,   0]]], dtype=uint8)
